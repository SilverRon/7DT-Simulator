# %%
import os
import glob
import numpy as np
# from ccdproc import ImageFileCollection
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.table import Table, hstack
from scipy.optimize import curve_fit

# %%
##	Plot presetting
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["axes.titlesize"] = 14
mpl.rcParams["axes.labelsize"] = 20
plt.rcParams['savefig.dpi'] = 500
plt.rc('font', family='serif')
# default_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
# intbl = Table.read('../data/7DT/Feige110/calib_7DT01_Feige110_20231012_022807_r_70.com.phot.cat', format='ascii')
# reftbl = Table.read('../data/7DT/Feige110/gaiaxp_dr3_synphot_Feige110.csv')
reftbl = Table.read('../data/7DT/LTT1020/gaiaxp_dr3_synphot_LTT1020.csv')
intbl = Table.read('../data/7DT/LTT1020/calib_7DT01_LTT1020_20231011_061246_r_70.com.phot.cat', format='ascii')

# %%
c_in = SkyCoord(intbl['ALPHA_J2000'], intbl['DELTA_J2000'], unit=(u.deg, u.deg))
c_ref = SkyCoord(reftbl['ra'], reftbl['dec'], unit="deg")

indx, sep, _ = c_in.match_to_catalog_sky(c_ref)

# %%
_mtbl = hstack([intbl, reftbl[indx]])
_mtbl['sep'] = sep.arcsec
_mtbl['delta_mag'] = _mtbl['MAG_AUTO_r'] - _mtbl['r_mag']

# %%
indx_sel = np.where(
	(_mtbl['sep']<1.0) &
	(_mtbl['FLAGS']==0) &
	(_mtbl['MAGERR_AUTO']<0.05) &
	(_mtbl['CLASS_STAR']>0.9)
	# (_mtbl['MAGERR_AUTO']<0.05) &
	# (_mtbl['sep']<1.0)
)

mtbl = _mtbl[indx_sel]

print(f"{len(mtbl)} selected")
# Out:
# 333 selected

# %%
plt.plot(mtbl['X_IMAGE'], mtbl['Y_IMAGE'], '.')

# %%
# import numpy as np
from sklearn.linear_model import HuberRegressor
# from sklearn.datasets import make_regression
# 샘플 데이터 생성
X, y = mtbl['bp_rp'].reshape(-1, 1), mtbl['delta_mag'].reshape(-1, 1)
# Huber Regressor 모델 생성
huber = HuberRegressor(epsilon=1.35) # epsilon은 Huber loss에서의 델타 값
huber.fit(X, y)
# 예측값 생성
y_pred = huber.predict(X)
# 예측 결과 출력
print("Predicted values:", y_pred)
# Out:
# Predicted values: [-8.83095471e-03  1.06447152e-03  3.52117204e-03  1.15530982e-02
#   2.03836605e-03 -5.34271760e-03  2.59712423e-04 -3.89073952e-03
#   3.67985962e-02  4.53322983e-02  1.31783370e-02 -1.62268578e-03
#   9.68948662e-03  3.63249816e-03  2.43199245e-02  5.79552516e-03
#   5.89475425e-03  1.02148991e-02  3.24299610e-03  8.91921150e-02
#  -2.59864293e-03 -5.57533931e-04  6.14817867e-03  4.20791541e-03
#   6.15829020e-02  2.68995465e-02  1.07570347e-01  5.08677104e-04
#   8.56390537e-03  1.96495790e-02  1.34203425e-03  3.71261533e-04
#   1.48633919e-02 -7.20900501e-03  1.72539211e-02  1.81046155e-02
#   8.20394905e-03  9.99981802e-05  2.95571580e-02  1.49151248e-02
#   4.91305519e-03  2.24535348e-03 -5.00288582e-03 -8.54152832e-05
#   9.15658087e-02  6.87794641e-02 -1.62000994e-03  3.37590538e-04
#   4.03803205e-02  1.17168819e-02  5.33818857e-04  4.29570436e-02
#   1.85549372e-02  1.08138963e-01  2.19268310e-02  3.40789478e-03
#  -3.17746073e-03  2.64856923e-03  6.46789054e-02  5.51306138e-02
#  -3.36163858e-04  1.30030136e-02  1.31721091e-01  2.13848617e-02
#   3.74159442e-03  4.23544220e-02  2.85449747e-03  4.12669157e-02
#   6.25289231e-02  3.25566640e-02 -6.18845050e-03 -3.94838159e-03
#   7.76476462e-02 -2.58777233e-03  4.88808067e-03  5.11073292e-03
#   5.20125904e-02 -2.88027517e-03 -5.42254684e-03  8.23701706e-02
#   1.43754969e-02  6.75392211e-03  1.54714767e-02  3.18893762e-02
#  -2.57003570e-04  5.94236192e-03 -3.07973680e-03  8.15360979e-03
#   5.51245374e-02  9.18793373e-03  1.33077342e-03  1.00453177e-02
#   5.76774567e-02  3.70403138e-02  3.87597087e-02  4.62109775e-02
#   9.81112496e-02 -6.53696957e-04  2.07111073e-02 -3.67605905e-03
#   5.97222450e-02  5.34893849e-03  7.99207729e-02  9.89764473e-03
#   4.13343135e-02  5.46284477e-02 -9.81404744e-03  1.01695204e-01
#   8.82362916e-03 -6.08899842e-03  1.99070264e-03  8.33280101e-02
#   1.54369695e-02  6.54364563e-03  1.40514972e-02  3.87187441e-03
#   4.35452918e-03  1.61795711e-02  3.06031422e-03  1.66169038e-02
#   7.67312914e-03  2.09751328e-03  2.92222969e-03  5.75811913e-03
#   1.78923878e-02  7.22066028e-02 -1.52022338e-03  8.62550545e-03
#   1.14392635e-02  7.02476087e-02  8.33813131e-03  4.87506290e-02
#   5.96629862e-02 -1.60891635e-03  7.72603275e-03  3.41373054e-02
#   1.07439565e-01 -1.22142116e-03  2.34022395e-05  4.65092222e-02
#   4.87949568e-03  3.94497969e-02  4.04154409e-02  1.22005959e-02
#   1.92118561e-02  3.55236696e-02  2.22193987e-03  3.75013389e-02
#   9.86633648e-02  1.07394968e-01  8.95797866e-03  1.49977971e-02
#   2.12758212e-02  8.46614707e-02 -5.45069892e-03  8.64819435e-03
#  -3.76748361e-03  5.39465077e-03  1.14418836e-02  3.12787920e-03
#  -7.83175119e-03  2.31681981e-02  1.24960970e-01 -4.25024068e-04
#  -1.56046783e-02  2.29317764e-02  7.87586945e-05  3.08779733e-03
#   1.42571467e-02  6.20616545e-02  1.44772346e-02  1.05944216e-01
#   1.68610277e-03  3.23728672e-02 -1.78914537e-03  1.30674011e-02
#   2.17533473e-02  9.25400377e-02  7.51240497e-02  2.01972902e-02
#   3.54557144e-02  5.72387860e-02  2.30360876e-03  4.24612327e-02
#   1.36593193e-02  3.26973128e-02 -5.53805397e-03  4.11704832e-03
#   6.70503227e-03  8.87584058e-02  1.07528146e-01  4.47064952e-03
#   4.16069797e-03  8.75151434e-02  1.36699112e-02  9.33252298e-02
#   8.16509361e-03  4.97777616e-02 -1.63795118e-04 -4.84395203e-03
#   8.26235393e-02  3.17410239e-04  5.71859474e-03  1.97921790e-02
#   2.55660301e-02  1.11962637e-02  6.92506442e-03  2.76394164e-02
#   1.26683663e-02  1.52181730e-03 -4.81334711e-03  5.59795892e-03
#   1.72967346e-02  3.64858573e-02  2.11157167e-02  2.14737777e-02
#  -2.96802045e-03  2.91289677e-02 -1.39273072e-03 -3.46165731e-03
#   9.35494987e-02  2.01848029e-02 -2.30792399e-03  6.14077459e-02
#   2.25024712e-02 -4.69834170e-03  9.23308205e-02  7.66282520e-04
#  -5.70679917e-03 -1.37383259e-03  2.69001039e-02  1.40106998e-03
#   4.32616993e-02  9.49870941e-02  6.76914095e-03  3.73320920e-02
#   5.20579682e-02 -1.95047627e-03  1.42163959e-02  3.77539829e-02
#   1.10531062e-02  7.08405396e-03  5.48468074e-02  2.31097755e-02
#   1.09108509e-01  1.82223617e-03  2.55493618e-02  7.60311131e-03
#  -6.46115408e-04  2.51196664e-02  5.02301460e-02  9.73827416e-04
#   3.42930151e-03 -2.70026914e-03  8.05897888e-02  3.03629763e-02
#   3.54469622e-02  1.67082818e-03  1.18274276e-02 -1.90978119e-03
#   5.38140444e-02 -7.14528655e-03  1.23229041e-02 -2.69435080e-04
#  -1.13674845e-02  3.89722708e-02  6.39484566e-02  1.31666859e-02
#   9.54136769e-03  2.57403591e-03 -2.53542620e-03  7.14616599e-02
#  -7.96688114e-03 -1.02290723e-03  1.02824464e-01 -4.48349399e-03
#   6.77293173e-03  2.22850591e-02 -7.77901483e-03  3.19878898e-03
#   3.74716259e-02  3.53555468e-03 -1.56783104e-03  1.06542944e-02
#   1.30229709e-02  1.51757963e-02  3.97304257e-02  2.36002440e-03
#   7.81640835e-02  2.56455898e-03  7.31830060e-02  9.73614659e-03
#   4.99204823e-03  7.90911508e-02  1.85306316e-02  1.69584079e-02
#   9.32969662e-02  5.25975403e-02  3.75366823e-02  5.08631495e-02
#  -2.71197594e-03  2.99950482e-02  4.82584416e-02  3.66810265e-02
#   1.12624350e-02 -5.66554663e-03 -3.48328703e-03  8.01506722e-02
#   6.06402256e-02  8.36160532e-02  4.41092161e-02  5.83039936e-02
#   2.25233204e-02  8.53135850e-04  1.08331390e-03  3.45937035e-02
#   9.81408965e-04  6.66026768e-03 -3.64255530e-03  1.40117498e-02
#   9.21519385e-03  2.27339406e-03  9.19488999e-02  5.93940734e-03
#  -2.54507037e-03 -1.64643386e-03  1.50257820e-02 -3.94726666e-03
#   1.04682678e-02  7.69303071e-03 -6.31287710e-03  2.42965201e-03
#   8.03705371e-02]
# /Users/paek/opt/miniconda3/envs/sdt/lib/python3.11/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
huber.get_params()
# Out:
# {'alpha': 0.0001,
#  'epsilon': 1.35,
#  'fit_intercept': True,
#  'max_iter': 100,
#  'tol': 1e-05,
#  'warm_start': False}

# %%
plt.plot(mtbl['bp_rp'], mtbl['delta_mag'], '.', alpha=0.5)
plt.plot(X, y_pred)
plt.xlabel("BP-RP [mag]")
plt.ylabel(r"$\Delta m$ [mag]")
plt.xlim(-0, 3.5)
plt.ylim(-0.2, +0.2)
# Out:
# (-0.2, 0.2)
