# %%
import os
import glob
import numpy as np
# from ccdproc import ImageFileCollection
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.table import Table, hstack
from scipy.optimize import curve_fit

# %%
##	Plot presetting
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["axes.titlesize"] = 14
mpl.rcParams["axes.labelsize"] = 20
plt.rcParams['savefig.dpi'] = 500
plt.rc('font', family='serif')
# default_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %% [markdown]
# ## 7DT

# %%
import sys
sys.path.append('..')
from util.helper import *
from util.sdtpy import *
register_custom_filters_on_speclite('../util')
# Out:
# Use `med25nm`, `med50nm`, `broad` as `group_name`

# %%
#	Subsequent filter info [AA]
bandmin=4000
bandmax=9000
bandwidth=250
bandstep=125
#	Maximum transmission of each filters
bandrsp=0.95
#	Wavelength bin [AA]
lammin=1000
lammax=10000
lamres=1000
#	Seeing Condition
seeing = 1.5
#
exptime = 180

# %%
#	Exposure Time [s]
sdt = SevenDT()
sdt.echo_optics()
filterset = sdt.generate_filterset(bandmin=bandmin, bandmax=bandmax, bandwidth=bandwidth, bandstep=bandstep, bandrsp=bandrsp, lammin=lammin, lammax=lammax, lamres=lamres)
T_qe = sdt.get_CMOS_IMX455_QE()
sdt.get_optics()
s = sdt.get_sky()
sdt.smooth_sky()
totrsptbl = sdt.calculate_response()
Npix_ptsrc, Narcsec_ptsrc = sdt.get_phot_aperture(exptime=exptime, fwhm_seeing=seeing, optfactor=1.0, verbose=False)
outbl_ris = sdt.get_depth_table(Nsigma=5)
sdt.get_speclite()
# Out:
# D             : 50.5cm
# D_obscuration : 29.8cm
# Deff          : 40.770cm

# %% [markdown]
# ## Initial Setting

# %%
path_save = '../output/GALAH'
if not os.path.exists(path_save): os.makedirs(path_save)

# %%
try:
	print(intbl[:3])
except:
	intbl = Table.read('../data/GALAH/GALAH_DR3_main_allstar_v2.fits')
# Out:
#     star_id         sobject_id   ...   bc_ks        ruwe_dr2
#                                  ...    mag
# ---------------- --------------- ... --------- ------------------
# 03325271-6840304 131116000501002 ... 2.1981099 1.0987638037798317
# 03345385-6836362 131116000501003 ...  2.669922  1.184694482545447
# 03422255-6841522 131116000501004 ... 1.9896321 0.9910400074815263

# %% [markdown]
# ## Sample Spectrum

# %%
colors = ['blue', 'green', 'red', 'purple']

# %%
spectra = sorted(glob.glob('../data/GALAH/sample/*fits'))
print(f"{len(spectra)} spectra")
# Out:
# 4 spectra

# %%
from astropy.io import fits
for ss, _specfile in enumerate(spectra):
	# _sptbl = Table.read(_specfile)
	# print(_sptbl)
	_data, _hdr = fits.getdata(_specfile, header=True)
	# det = _hdr['DETECYS']
	plt.plot(_data, c=colors[ss], alpha=0.75,)# label=f"{det}")

plt.legend()

# %%
_hdr
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    1 / Number of axes
# NAXIS1  =                 4096 / Axis length
# EXTEND  =                    T / File may contain extensions
# ORIGIN  = 'GALAH DR3'          / FITS file originator
# DATE    = '2018-02-17T18:48:18' / Date FITS file was generated
# IRAF-TLM= '2018-02-17T18:48:18' / Time of last modification
# OBJECT  = '170418003701205'    / Name of t
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# LONGSTRN= 'OGIP 1.0'           / The HEASARC Long String Convention may be used.
# COMMENT   This FITS file may contain long string keyword values that are
# COMMENT   continued over multiple keywords.  The HEASARC convention uses the &
# COMMENT   character at the end of each substring which is then continued
# COMMENT   on the next keyword which has the name CONTINUE.
# DCT_DATE= 'Dec  5 2016'        / DCT release date
# DCT_VER = 'r3_139  '           / DCT version number
# DETECXE =                 4096 / Last column of detector
# DETECXS =                    1 / First column of detector
# DETECYE =                 4112 / Last row of detector
# DETECYS =                    1 / First row of detector
# FIRMVSYS= 'System: AAO2 CCD Controller System Controller V1.28 130312' / System
# FIRMVSEQ= 'Sequencer: AAO2 CCD Controller Sequencer V1.3 110321' / Sequencer fir
# DETECTOR= 'E2V8-IR '           / Detector name
# XPIXSIZE=                  15. / X Pixel size in microns
# YPIXSIZE=                  15. / Y Pixel size in microns
# CONFIGID=                   16 / Controller configuration Id
# DETECTID=                   16 / Controller detector Id
# ABCKPLID=                    6 / Analog backplane Id
# VIDPBID =                    7 / Video personality board Id
# CLKPBID =                   21 / Clock personality board Id
# BRDID_1 =                65537 / Controller board #1 Id
# BRDSN_1 =                  123 / Controller board #1 serial #
# BRDID_2 =               327681 / Controller board #2 Id
# BRDSN_2 =                  126 / Controller board #2 serial #
# BRDID_3 =               131074 / Controller board #3 Id
# BRDSN_3 =                  117 / Controller board #3 serial #
# BRDID_4 =               131074 / Controller board #4 Id
# BRDSN_4 =                   82 / Controller board #4 serial #
# BRDID_5 =               131074 / Controller board #5 Id
# BRDSN_5 =                  133 / Controller board #5 serial #
# BRDID_6 =               131074 / Controller board #6 Id
# BRDSN_6 =                  134 / Controller board #6 serial #
# BRDID_7 =               196610 / Controller board #7 Id
# BRDSN_7 =                   95 / Controller board #7 serial #
# BRDID_8 =               262146 / Controller board #8 Id
# BRDSN_8 =                   74 / Controller board #8 serial #
# BRDID_9 =               458754 / Controller board #9 Id
# BRDSN_9 =                  130 / Controller board #9 serial #
# BRDID_10=               393217 / Controller board #10 Id
# BRDSN_10=                   57 / Controller board #10 serial #
# METHOD  = 'Normal ccd control method' / Observing method
# SPEED   = 'FAST    '           / Readout speed
# READAMP = 'LEFT_TWO'           / Readout amplifier
# EXPOSED =                1200. / Exposure time (seconds)
# ELAPSED =               1200.4 / Elapsed time (seconds)
# TOTALEXP=               3600.0 / Total exposure (seconds)
# RO_GAIN =                 2.75 / Readout amplifier (inverse) gain (e-/ADU)
# RO_NOISE=                 4.87 / Readout noise (electrons)
# DETTEMP =             167.7141 / Detector temperature (K)
# HTRVOLTS=             6.506341 / Detector heater voltage
# SPECTID = 'RR      '           / Spectrograph ID
# SFILT1  = '        '           / Lower filter wheel position
# SFILT2  = '        '           / Upper filter wheel position
# TELESCOP= 'Anglo-Australian Telescope' / Telescope Name
# ALT_OBS =                 1164 / Altitude of observatory in metres
# LAT_OBS =            -31.27704 / Observatory latitude in degrees
# LONG_OBS=             149.0661 / Observatory longitude in degrees
# RCT_VER = 'r3_73   '           / Run Control Task version number
# RCT_DATE= '13-Jan-2015'        / Run Control Task version date
# RUNCMD  = 'RUN     '           / Run command
# RADECSYS= 'FK5     '           / FK5 reference system
# EQUINOX =                2000. / J2000 equinox
# INSTRUME= 'HERMES-2dF'         / Instrument in use
# AAOPRGID= '2017A/18'           / AAO Proposal ID
# TDFCTVER= 'r11_73  '           / 2dF Control Task Version
# TDFCTDAT= '23-Feb-2017'        / 2dF Control Task Version Date
# AAOMOSFT=                    1 / Indicates file generated by AAOmega software.
# DUMMY   =                    0
# HARTMANA= 'Open    '           / Hartmann shutter A position
# HARTMANB= 'Open    '           / Hartmann shutter B position
# DCHROIC1= 'GA Blue '           / Dichroic1 name
# DCHROIC2= 'GA Green'           / Dichroic2 name
# DCHROIC3= 'GA Red  '           / Dichroic3 name
# ELECTEMP=                 18.8 / Computer or electronics rack temperature in deg
# SPEC1TMP=                 19.5 / Spectrograph room 1 temperature in degrees
# SPEC2TMP=                 19.6 / Spectrograph room 2 temperature in degrees
# FRM1TEMP=                 17.6 / Spectrograph table or frame 1 temperature in de
# FRM2TEMP=                  18. / Spectrograph frame 2 temperature in degrees
# SLITTEMP=                 18.7 / Slit temperature in degrees
# SLITMASK= 'OUT     '           / Indicates the state of the slit mask
# HPOSCONF= 'YES     '           / TRUST value of the spectrograph
# SLITDITH= 'OFF     '           / Is slit dithering enabled
# SOURCE  = 'Plate 0 '           / Source slit. Slit encoder Value = -91405
# FLAPS   = 'OPEN    '           / 2df Flap Status
# RUN     =                   39 / Run number
# OBSNUM  =                   39 / Observation number
# GRPNUM  =                   39 / Group Number
# GRPMEM  =                    1 / Group member
# GRPMAX  =                    0 / Group maximum
# OBSTYPE = 'OBJECT  '           / Observation type
# UTDATE  = '2017:04:18'         / UT date
# EPOCH   =     2017.29524668597 / Current Epoch, Years A.D.
# UTSTART = '14:07:57'           / UT start
# UTEND   = '14:27:58'           / UT end
# STSTART = '13:51:44'           / ST start
# STEND   = '14:11:48'           / ST end
# UTMJD   =     57861.5888520497 / Modified Julian Date (UTC)
# TOPEND  = '2DF     '           / Telescope top-end
# AXIS    = 'A       '           / Current optical axis
# AXIS_X  = -2.60344946755821E-05 / Optical axis x (mm)
# AXIS_Y  = -9.54598138104676E-05 / Optical axis y (mm)
# TRACKING= 'TRACKING'           / Telescope is tracking.
# TELFOC  =                 40.2 / Telescope Focus (mm)
# MEANRA  =     211.574362416553 / 14 06 17.85
# MEANDEC =    -33.7306407196139 / -33 43 50.3
# TEL_PA  =     90.0765954211635 / Rotator position angle
# HASTART =    -3.89966563728754 / HA at start of run
# ZDSTART =      4.1506205127283 / ZD at start of run
# APPRA   =     3.69721088970719 / Current apparent place position right ascension
# APPDEC  =   -0.590131818930845 / Current apparent place position declination
# WINDOW  = 'HERMES_2ROs_LR'     / Observing window (file name)
# NDFCLASS= 'MFOBJECT'           / Data Reduction class name (NDFCLASS)
# CFG_FILE= 'gf1_5994_3701550867_1201400_p0.sds' / 2dF fibre configuration filenam
# PARKMASK=                    F / 2dF park position mask NOT installed
# TDFCTEVT= '106     '           / 2dF Control Task Event
# PISTON  =     3213.95238095238 / Camera focus piston 134986 (encoder)
# TILTSPEC=     12096.9708641192 / Camera focus spectral 145824 (encoder)
# TILTSPAT=                    0 / Camera focus spatial (encoder)
# GRATID  = '24      '           / VPH grating Id ?
# GRATTILT=                    0 / Grating tilt to be symmetric (degree)
# GRATLPMM=                2378. / Disperser ruling (lines/mm)
# ORDER   =                    1 / Dispersion order
# DISPENC =                    0 / Disperser angle reading (encoder unit)
# CAMENC  =                    0 / Camera angle reading (encoder unit)
# GRATANGL=                    0 / Disperser angle reading (degree)
# GRATANGR=                    0 / Requested disperser angle reading (degree)
# CAMANGL =                    0 / Camera angle reading (degree)
# CAMANGR =                    0 / Requested camera angle reading (degree)
# LAMBDAC =                7781. / Central wavelength in Angstrom
# LAMBDAB =                7781. / Optimal blaze wavelength in Angstrom
# LAMBDCR =                7781. / Requested central wavelength in Angstrom
# LAMBDBR =                7781. / Requested optimal wavelength in Angstrom
# DISPERS =                0.073 / Central dispersion (Angstrom/pixel)
# SPLYTEMP=                 16.6 / IR camera supply line temperature in degrees
# RTRNTEMP=                  6.5 / IR camera return line temperature in degrees
# CAMRTEMP=                 18.9 / IR camera temperature in degrees
# HAEND   =     1.11696700286496 / HA at end of run
# ZDEND   =     2.70383673338308 / ZD at end of run
# WINDOXS1=                    1 / First column of window 1
# WINDOXE1=                 4096 / Last column of window 1
# WINDOYS1=                    1 / First row of window 1
# WINDOYE1=                 2056 / Last row of window 1
# WINDOXS2=                 4100 / First column of window 2
# WINDOXE2=                 4149 / Last column of window 2
# WINDOYS2=                    1 / First row of window 2
# WINDOYE2=                 2056 / Last row of window 2
# XEFFSIZE=                  15. / Effective X pixel size in microns
# YEFFSIZE=                  15. / Effective Y pixel size in microns
# RO_GAIN1=                  2.5 / Readout amplifier (inverse) gain (e-/ADU)
# RO_NOIS1=                 4.27 / Readout noise (electrons)
# FILEORIG= '/data/aatobs/OptDet_data/170418/ccd_4/18apr40039.fits' / The filename
# WCSDIM  =                    1
# LTM1_1  =                   1.
# FIXPIX  = 'Feb 17 15:42 Bad pixel file is tmp/badpix4.dat'
# CTYPE1  = 'LINEAR  '
# CDELT1  =   0.0735803476037851
# REFSPEC = '18apr40038.ms'
# MOLECFIT= 'SUCCESS '
# NCOMBINE=                    3
# CRVAL1  =     7585.90722656251
# CRPIX1  =                   1.
# CTYPE2  = 'Wavelength'
# CUNIT1  = 'Angstroms'
# PIPE_VER=                  5.3
# COMB0   = '18apr40039.fits'
# COMB1   = '18apr40040.fits'
# COMB2   = '18apr40041.fits'
# BARYEFF =             6.957891
# W_RMS   =            0.0351372

# %%
for _specfile in spectra:
    # FITS 파일 읽기
    fits_file = _specfile
    with fits.open(fits_file) as hdul:
        header = hdul[0].header
        flux = hdul[0].data

        # 파장 배열 계산
        crval1 = header['CRVAL1']
        cdelt1 = header['CDELT1']
        crpix1 = header['CRPIX1']
        npix = len(flux)
        wavelength = crval1 + (np.arange(npix) - crpix1 + 1) * cdelt1

    # 그래프 그리기
    plt.plot(wavelength, flux)
    plt.xlabel('Wavelength (Angstrom)')
    plt.ylabel('Flux')
    plt.title('Spectrum of Star 170418003701205 (Near-Infrared Camera)')
    # plt.show()
